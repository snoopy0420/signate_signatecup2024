# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/competitions/probspace_pricing/notebooks
# Out:
# /content/drive/MyDrive/competitions/probspace_pricing/notebooks

# %%
# !git remote -v
# Out:
# origin	https://SubaruIshiuzka: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@github.com/snoopy0420/probspace_pricing.git (fetch)
# origin	https://SubaruIshiuzka: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@github.com/snoopy0420/probspace_pricing.git (push)

# %% [markdown]
# # push

# %%
# !git add .

# %%
# !git commit -m "notebookを追加"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %% [markdown]
# # pull

# %%
# !git fetch origin main
# Out:
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 3 (delta 2), reused 3 (delta 2), pack-reused 0
# Unpacking objects: 100% (3/3), done.
# From https://github.com/snoopy0420/probspace_pricing
#  * branch            main       -> FETCH_HEAD
#    771c098..87ee062  main       -> origin/main

# %%
# !git merge origin main
# Out:
# Updating 771c098..87ee062
# Fast-forward
#  .gitignore | 4 ++--
#  1 file changed, 2 insertions(+), 2 deletions(-)

# %% [markdown]
# # その他

# %%
# !git stash -- ../.gitignore
# Out:
# Saved working directory and index state WIP on main: 04ac54e notebookを追加

# %%
# !git remote set-url origin https://SubaruIshiuzka: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@github.com/snoopy0420/probspace_pricing.git

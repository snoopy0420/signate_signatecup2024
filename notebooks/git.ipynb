# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/competitions/probspace_pricing/
# Out:
# /content/drive/MyDrive/competitions/probspace_pricing

# %% [markdown]
# # push

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/competitions/probspace_pricing/.git/

# %%
# !git add ./data/features/train.pkl
# !git add ./data/features/test.pkl

# %%
# !git add ./

# %%
# !git commit -m "train,testデータを修正"
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Changes not staged for commit:
# 	deleted:    .gitignore.swp
# 	modified:   code/code_run.ipynb
# 	modified:   data/features/Description_pred.csv
# 	modified:   data/features/OwnerDetail_pred.csv
# 	modified:   data/features/Review_pred.csv
# 	modified:   notebooks/bert_vectrize.ipynb
# 	modified:   notebooks/git.ipynb
# 	modified:   notebooks/pricing_EDA.ipynb
#
# Untracked files:
# 	data/features/Description_reg_en_vect_svd.pkl
# 	data/features/Description_reg_vect_svd.pkl
# 	data/features/OwnerDetail_reg_en_vect_svd.pkl
# 	data/features/OwnerDetail_reg_vect_svd.pkl
# 	data/features/Review_reg_en_vect_svd.pkl
# 	data/features/Review_reg_vect_svd.pkl
# 	data/features/conbine_PT_Am_reg_vect_svd.pkl
# 	notebooks/bert_reg/
# 	notebooks/bert_reg_Amenities/
# 	notebooks/bert_reg_Description/
# 	notebooks/bert_reg_OwnerDetail/
# 	notebooks/bert_reg_PropertyType/
# 	notebooks/bert_reg_Review/
# ...

# %%
# !git push origin main
# Out:
# Everything up-to-date

# %% [markdown]
# # pull

# %%
# !git fetch origin main
# Out:
# From https://github.com/snoopy0420/probspace_pricing
#  * branch            main       -> FETCH_HEAD

# %%
# !git merge origin main
# Out:
# Already up to date.

# %% [markdown]
# # その他

# %%
# スタッシュ
# !git stash -- ../.gitignore
# Out:
# Saved working directory and index state WIP on main: 04ac54e notebookを追加

# %%
# priveteプロジェクトにアクセス
# !git remote set-url origin https://SubaruIshiuzka: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@github.com/snoopy0420/probspace_pricing.git

# %%
# インデックス削除
# !git reset

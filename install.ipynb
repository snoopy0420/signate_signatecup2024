# %%
# !conda list
# Out:
# # packages in environment at /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024:
# #
# # Name                    Version                   Build  Channel
# appnope                   0.1.4              pyhd8ed1ab_0    conda-forge
# asttokens                 2.4.1              pyhd8ed1ab_0    conda-forge
# backcall                  0.2.0              pyh9f0ad1d_0    conda-forge
# ca-certificates           2024.7.4             h8857fd0_0    conda-forge
# comm                      0.2.2              pyhd8ed1ab_0    conda-forge
# debugpy                   1.6.7            py39hcec6c5f_0
# decorator                 5.1.1              pyhd8ed1ab_0    conda-forge
# executing                 2.0.1              pyhd8ed1ab_0    conda-forge
# importlib-metadata        8.2.0              pyha770c72_0    conda-forge
# importlib_metadata        8.2.0                hd8ed1ab_0    conda-forge
# ipykernel                 6.29.5             pyh57ce528_0    conda-forge
# ipython                   8.12.0             pyhd1c38e8_0    conda-forge
# jedi                      0.19.1             pyhd8ed1ab_0    conda-forge
# jupyter_client            8.6.2              pyhd8ed1ab_0    conda-forge
# jupyter_core              5.7.2            py39hecd8cb5_0
# libcxx                    14.0.6               h9765a3e_0
# libffi                    3.4.4                hecd8cb5_1
# libsodium                 1.0.18               hbcb3906_1    conda-forge
# matplotlib-inline         0.1.7              pyhd8ed1ab_0    conda-forge
# ncurses                   6.4                  hcec6c5f_0
# nest-asyncio              1.6.0              pyhd8ed1ab_0    conda-forge
# openssl                   3.3.1                h87427d6_2    conda-forge
# packaging                 24.1               pyhd8ed1ab_0    conda-forge
# parso                     0.8.4              pyhd8ed1ab_0    conda-forge
# pexpect                   4.9.0              pyhd8ed1ab_0    conda-forge
# pickleshare               0.7.5                   py_1003    conda-forge
# pip                       24.0             py39hecd8cb5_0
# platformdirs              4.2.2              pyhd8ed1ab_0    conda-forge
# prompt-toolkit            3.0.47             pyha770c72_0    conda-forge
# prompt_toolkit            3.0.47               hd8ed1ab_0    conda-forge
# psutil                    6.0.0            py39hded5825_0    conda-forge
# ptyprocess                0.7.0              pyhd3deb0d_0    conda-forge
# pure_eval                 0.2.3              pyhd8ed1ab_0    conda-forge
# pygments                  2.18.0             pyhd8ed1ab_0    conda-forge
# python                    3.9.19               h5ee71fb_1
# python-dateutil           2.9.0              pyhd8ed1ab_0    conda-forge
# python_abi                3.9                      2_cp39    conda-forge
# pyzmq                     24.0.1           py39hed8f129_1    conda-forge
# readline                  8.2                  hca72f7f_0
# setuptools                72.1.0           py39hecd8cb5_0
# six                       1.16.0             pyh6c4a22f_0    conda-forge
# sqlite                    3.45.3               h6c40b1e_0
# stack_data                0.6.2              pyhd8ed1ab_0    conda-forge
# tk                        8.6.14               h4d00af3_0
# tornado                   6.4.1            py39hded5825_0    conda-forge
# traitlets                 5.14.3             pyhd8ed1ab_0    conda-forge
# typing_extensions         4.12.2             pyha770c72_0    conda-forge
# tzdata                    2024a                h04d1e81_0
# wcwidth                   0.2.13             pyhd8ed1ab_0    conda-forge
# wheel                     0.43.0           py39hecd8cb5_0
# xz                        5.4.6                h6c40b1e_1
# zeromq                    4.3.5                hcec6c5f_0
# zipp                      3.19.2             pyhd8ed1ab_0    conda-forge
# zlib                      1.2.13               h4b97444_1

# %%
# !conda install -y pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bottleneck-1.3.7           |   py39h7b7cdfe_0         134 KB
#     intel-openmp-2023.1.0      |   ha357a0b_43548         638 KB
#     mkl-2023.1.0               |   h8e150cf_43560       181.0 MB
#     mkl-service-2.4.0          |   py39h6c40b1e_1          44 KB
#     mkl_fft-1.3.8              |   py39h6c40b1e_0         195 KB
#     mkl_random-1.2.4           |   py39ha357a0b_0         271 KB
#     numexpr-2.8.7              |   py39h827a554_0         135 KB
#     numpy-1.26.4               |   py39h827a554_0          12 KB
#     numpy-base-1.26.4          |   py39ha186be2_0         6.7 MB
#     pandas-2.2.2               |   py39h6d0c2b6_0        12.2 MB
#     python-tzdata-2023.3       |     pyhd3eb1b0_0         140 KB
#     pytz-2024.1                |   py39hecd8cb5_0         216 KB
#     tbb-2021.8.0               |       ha357a0b_0         172 KB
#     ------------------------------------------------------------
#                                            Total:       201.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   bottleneck         pkgs/main/osx-64::bottleneck-1.3.7-py39h7b7cdfe_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2023.1.0-ha357a0b_43548
#   mkl                pkgs/main/osx-64::mkl-2023.1.0-h8e150cf_43560
#   mkl-service        pkgs/main/osx-64::mkl-service-2.4.0-py39h6c40b1e_1
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.3.8-py39h6c40b1e_0
#   mkl_random         pkgs/main/osx-64::mkl_random-1.2.4-py39ha357a0b_0
#   numexpr            pkgs/main/osx-64::numexpr-2.8.7-py39h827a554_0
#   numpy              pkgs/main/osx-64::numpy-1.26.4-py39h827a554_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.26.4-py39ha186be2_0
#   pandas             pkgs/main/osx-64::pandas-2.2.2-py39h6d0c2b6_0
#   python-tzdata      pkgs/main/noarch::python-tzdata-2023.3-pyhd3eb1b0_0
#   pytz               pkgs/main/osx-64::pytz-2024.1-py39hecd8cb5_0
#   tbb                pkgs/main/osx-64::tbb-2021.8.0-ha357a0b_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2024.7.4~ --> pkgs/main::ca-certificates-2024.7.2-hecd8cb5_0
#   openssl             conda-forge::openssl-3.3.1-h87427d6_2 --> pkgs/main::openssl-3.0.14-h46256e1_0
#
#
#
# Downloading and Extracting Packages
# tbb-2021.8.0         | 172 KB    |                                       |   0%
# mkl_random-1.2.4     | 271 KB    |                                       |   0%
#
# python-tzdata-2023.3 | 140 KB    |                                       |   0%
#
#
# numpy-base-1.26.4    | 6.7 MB    |                                       |   0%
#
#
#
# numexpr-2.8.7        | 135 KB    |                                       |   0%
#
#
#
#
# numpy-1.26.4         | 12 KB     |                                       |   0%
#
#
#
#
#
# intel-openmp-2023.1. | 638 KB    |                                       |   0%
#
#
#
#
#
#
# pytz-2024.1          | 216 KB    |                                       |   0%
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 134 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.8        | 195 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  |                                       |   0%
#
#
#
# numexpr-2.8.7        | 135 KB    | ####3                                 |  12%
#
# python-tzdata-2023.3 | 140 KB    | ####2                                 |  11%
#
#
# tbb-2021.8.0         | 172 KB    | ###4                                  |   9%
# mkl_random-1.2.4     | 271 KB    | ##1                                   |   6%
#
#
#
# numexpr-2.8.7        | 135 KB    | ###################################1  |  95%
#
# python-tzdata-2023.3 | 140 KB    | #################################7    |  91%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #2                                    |   3%
#
#
#
#
#
# intel-openmp-2023.1. | 638 KB    | 9                                     |   3%
#
#
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##4                                   |   7%
#
#
#
#
#
# intel-openmp-2023.1. | 638 KB    | ##################5                   |  50%
# mkl_random-1.2.4     | 271 KB    | ################################7     |  88%
#
#
#
#
#
#
# pytz-2024.1          | 216 KB    | ##7                                   |   7%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###1                                  |   9%
#
# python-tzdata-2023.3 | 140 KB    | ##################################### | 100%
#
#
#
#
#
# intel-openmp-2023.1. | 638 KB    | ####################################1 |  98%
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | #############5                        |  37%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #####4                                |  15%
#
#
#
# numexpr-2.8.7        | 135 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# tbb-2021.8.0         | 172 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   |                                       |   0%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #######5                              |  20%
#
#
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | 9                                     |   3%
# mkl_random-1.2.4     | 271 KB    | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ########9                             |  24%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.8        | 195 KB    | ###                                   |   8%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##3                                   |   6%
#
#
#
#
#
#
# pytz-2024.1          | 216 KB    | ##################################### | 100%
#
#
#
#
#
#
# pytz-2024.1          | 216 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  |                                       |   0%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###########8                          |  32%
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# mkl-service-2.4.0    | 44 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##9                                   |   8%
#
#
#
#
#
# intel-openmp-2023.1. | 638 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  |                                       |   0%
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 134 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# bottleneck-1.3.7     | 134 KB    | ##################################### | 100%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.8        | 195 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# mkl_fft-1.3.8        | 195 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ####3                                 |  12%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##############7                       |  40%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 1                                     |   0%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #################                     |  46%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ####8                                 |  13%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 2                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #####2                                |  14%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 2                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 2                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #####9                                |  16%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ######################9               |  62%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ######4                               |  17%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #########################5            |  69%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 3                                     |   1%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #######3                              |  20%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 4                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ############################3         |  77%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 4                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #############################5        |  80%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 4                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 5                                     |   1%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ################################      |  87%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 5                                     |   2%
#
#
# numpy-base-1.26.4    | 6.7 MB    | #################################1    |  89%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 5                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##########7                           |  29%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 6                                     |   2%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 6                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###########8                          |  32%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 6                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 7                                     |   2%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 7                                     |   2%
#
#
# numpy-base-1.26.4    | 6.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | 9                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #                                     |   3%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #                                     |   3%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #1                                    |   3%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #2                                    |   3%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #3                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #####################6                |  59%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #4                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ######################3               |  61%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #4                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #######################1              |  62%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #5                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #6                                    |   4%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #7                                    |   5%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #8                                    |   5%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #9                                    |   5%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##                                    |   5%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##                                    |   6%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##1                                   |   6%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##3                                   |   6%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ###################################8  |  97%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##5                                   |   7%
#
#
#
#
#
#
#
#
#
# pandas-2.2.2         | 12.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###2                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###3                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###5                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###6                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###9                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####3                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####5                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####8                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####9                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####2                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####3                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####4                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####5                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####7                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######1                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######2                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######3                               |  17%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######5                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######6                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######8                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######9                               |  19%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######                               |  19%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######1                              |  19%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######3                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######4                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######8                              |  21%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########                              |  22%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########1                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########2                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########3                             |  22%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########4                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########5                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########6                             |  23%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########8                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########9                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########                             |  24%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########1                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########2                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########3                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########4                            |  25%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########4                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########6                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########7                            |  26%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########9                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########                            |  27%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########2                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########3                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########4                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########5                           |  28%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########7                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########9                           |  30%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########                           |  30%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########1                          |  30%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########3                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########4                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########5                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########6                          |  31%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########7                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########8                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############                          |  33%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############1                         |  33%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############2                         |  33%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############3                         |  33%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############4                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############5                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############7                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############8                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############2                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############4                        |  36%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############5                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############6                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############7                        |  37%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############7                       |  40%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############9                       |  41%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############4                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############6                      |  42%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############7                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############9                      |  43%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################1                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################2                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################3                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################5                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################6                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################8                     |  46%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################                     |  46%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################1                    |  46%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################2                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################4                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################5                    |  47%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################6                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################7                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################8                    |  48%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################                    |  49%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################2                   |  49%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################3                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################5                   |  50%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################6                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################                   |  51%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################1                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################5                  |  53%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################6                  |  53%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################7                  |  53%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################                  |  54%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################1                 |  54%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################2                 |  55%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################2                 |  55%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################5                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################9                 |  57%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################                 |  57%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################2                |  57%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################3                |  58%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################4                |  58%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################5                |  58%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################7                |  59%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #####################9                |  59%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################1               |  60%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################2               |  60%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################3               |  60%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################5               |  61%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################7               |  61%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################               |  62%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################2              |  63%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################5              |  64%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################6              |  64%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #######################7              |  64%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################              |  65%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################2             |  65%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################4             |  66%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################6             |  66%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################7             |  67%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ########################9             |  67%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################2            |  68%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################4            |  69%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################6            |  69%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################7            |  70%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #########################9            |  70%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################            |  70%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################2           |  71%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################3           |  71%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################5           |  72%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################8           |  72%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################1          |  73%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################6          |  75%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################7          |  75%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###########################9          |  75%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################          |  76%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################2         |  76%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################5         |  77%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################6         |  77%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################7         |  78%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ############################9         |  78%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################         |  79%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################1        |  79%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################4        |  80%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################7        |  80%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################8        |  81%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################1       |  81%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################3       |  82%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################4       |  82%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################6       |  83%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##############################8       |  83%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################       |  84%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################1      |  84%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################2      |  85%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################7      |  86%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################8      |  86%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################1     |  87%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################2     |  87%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################3     |  88%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################5     |  88%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################8     |  89%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ################################9     |  89%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################1    |  90%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################2    |  90%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################4    |  90%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################5    |  91%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################6    |  91%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################    |  92%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################2   |  93%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################4   |  93%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################6   |  94%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################7   |  94%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################9   |  94%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################   |  95%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################1  |  95%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################3  |  96%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################5  |  96%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################6  |  96%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ###################################9  |  97%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################  |  97%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################2 |  98%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################5 |  99%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################6 |  99%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ####################################7 |  99%
#
#
#
#
#
#
#
#
#
#
#
# mkl-2023.1.0         | 181.0 MB  | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y numpy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# # All requested packages already installed.

# %%
# !conda install -y matplotlib
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h6c40b1e_8          20 KB
#     brotli-bin-1.0.9           |       h6c40b1e_8          17 KB
#     contourpy-1.2.0            |   py39ha357a0b_0         241 KB
#     fonttools-4.51.0           |   py39h6c40b1e_0         2.4 MB
#     freetype-2.12.1            |       hd8bbffd_0         592 KB
#     importlib_resources-6.4.0  |   py39hecd8cb5_0          61 KB
#     jpeg-9e                    |       h46256e1_3         253 KB
#     kiwisolver-1.4.4           |   py39hcec6c5f_0          63 KB
#     libbrotlicommon-1.0.9      |       h6c40b1e_8          68 KB
#     libbrotlidec-1.0.9         |       h6c40b1e_8          31 KB
#     libbrotlienc-1.0.9         |       h6c40b1e_8         300 KB
#     libdeflate-1.17            |       hb664fd8_1          67 KB
#     libpng-1.6.39              |       h6c40b1e_0         290 KB
#     libtiff-4.5.1              |       hcec6c5f_0         508 KB
#     libwebp-base-1.3.2         |       h6c40b1e_0         371 KB
#     lz4-c-1.9.4                |       hcec6c5f_1         167 KB
#     matplotlib-3.8.4           |   py39hecd8cb5_0           9 KB
#     matplotlib-base-3.8.4      |   py39hb47e01b_0         6.8 MB
#     openjpeg-2.5.2             |       hbf2204d_0         351 KB
#     pillow-10.4.0              |   py39h46256e1_0         751 KB
#     unicodedata2-15.1.0        |   py39h6c40b1e_0         517 KB
#     zstd-1.5.5                 |       hc035e20_2         599 KB
#     ------------------------------------------------------------
#                                            Total:        14.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/osx-64::brotli-1.0.9-h6c40b1e_8
#   brotli-bin         pkgs/main/osx-64::brotli-bin-1.0.9-h6c40b1e_8
#   contourpy          pkgs/main/osx-64::contourpy-1.2.0-py39ha357a0b_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/osx-64::fonttools-4.51.0-py39h6c40b1e_0
#   freetype           pkgs/main/osx-64::freetype-2.12.1-hd8bbffd_0
#   importlib_resourc~ pkgs/main/osx-64::importlib_resources-6.4.0-py39hecd8cb5_0
#   jpeg               pkgs/main/osx-64::jpeg-9e-h46256e1_3
#   kiwisolver         pkgs/main/osx-64::kiwisolver-1.4.4-py39hcec6c5f_0
#   lcms2              pkgs/main/osx-64::lcms2-2.12-hf1fd2bf_0
#   lerc               pkgs/main/osx-64::lerc-3.0-he9d5cce_0
#   libbrotlicommon    pkgs/main/osx-64::libbrotlicommon-1.0.9-h6c40b1e_8
#   libbrotlidec       pkgs/main/osx-64::libbrotlidec-1.0.9-h6c40b1e_8
#   libbrotlienc       pkgs/main/osx-64::libbrotlienc-1.0.9-h6c40b1e_8
#   libdeflate         pkgs/main/osx-64::libdeflate-1.17-hb664fd8_1
#   libpng             pkgs/main/osx-64::libpng-1.6.39-h6c40b1e_0
#   libtiff            pkgs/main/osx-64::libtiff-4.5.1-hcec6c5f_0
#   libwebp-base       pkgs/main/osx-64::libwebp-base-1.3.2-h6c40b1e_0
#   lz4-c              pkgs/main/osx-64::lz4-c-1.9.4-hcec6c5f_1
#   matplotlib         pkgs/main/osx-64::matplotlib-3.8.4-py39hecd8cb5_0
#   matplotlib-base    pkgs/main/osx-64::matplotlib-base-3.8.4-py39hb47e01b_0
#   openjpeg           pkgs/main/osx-64::openjpeg-2.5.2-hbf2204d_0
#   pillow             pkgs/main/osx-64::pillow-10.4.0-py39h46256e1_0
#   pyparsing          pkgs/main/osx-64::pyparsing-3.0.9-py39hecd8cb5_0
#   unicodedata2       pkgs/main/osx-64::unicodedata2-15.1.0-py39h6c40b1e_0
#   zstd               pkgs/main/osx-64::zstd-1.5.5-hc035e20_2
#
#
#
# Downloading and Extracting Packages
# kiwisolver-1.4.4     | 63 KB     |                                       |   0%
# freetype-2.12.1      | 592 KB    |                                       |   0%
#
# lz4-c-1.9.4          | 167 KB    |                                       |   0%
#
#
# libbrotlicommon-1.0. | 68 KB     |                                       |   0%
#
#
#
# libtiff-4.5.1        | 508 KB    |                                       |   0%
#
#
#
#
# zstd-1.5.5           | 599 KB    |                                       |   0%
#
#
#
#
#
# libbrotlienc-1.0.9   | 300 KB    |                                       |   0%
#
#
#
#
#
#
# libdeflate-1.17      | 67 KB     |                                       |   0%
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 371 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 517 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 253 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 61 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 241 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 351 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     |                                       |   0%
#
#
# libbrotlicommon-1.0. | 68 KB     | ########6                             |  23%
#
# kiwisolver-1.4.4     | 63 KB     | #########4                            |  26%
# freetype-2.12.1      | 592 KB    | 9                                     |   3%
#
#
#
# libtiff-4.5.1        | 508 KB    | #1                                    |   3%
#
# lz4-c-1.9.4          | 167 KB    | ############################3         |  77%
# freetype-2.12.1      | 592 KB    | #############9                        |  38%
#
#
#
# libtiff-4.5.1        | 508 KB    | ###########6                          |  31%
#
#
# libbrotlicommon-1.0. | 68 KB     | ##################################### | 100%
#
#
# libbrotlicommon-1.0. | 68 KB     | ##################################### | 100%
#
#
#
#
# zstd-1.5.5           | 599 KB    | 9                                     |   3%
#
#
#
#
#
# libbrotlienc-1.0.9   | 300 KB    | #9                                    |   5%
# freetype-2.12.1      | 592 KB    | #####################9                |  59%
#
#
#
# kiwisolver-1.4.4     | 63 KB     | ##################################### | 100%
#
#
#
#
#
#
# libdeflate-1.17      | 67 KB     | ########8                             |  24%
#
#
#
#
# zstd-1.5.5           | 599 KB    | #######9                              |  21%
#
# lz4-c-1.9.4          | 167 KB    | ##################################### | 100%
#
#
#
# libtiff-4.5.1        | 508 KB    | ####################################1 |  98%
#
#
#
#
#
# libbrotlienc-1.0.9   | 300 KB    | ###############7                      |  43%
# freetype-2.12.1      | 592 KB    | ###################################9  |  97%
#
#
#
#
#
#
# libdeflate-1.17      | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 17 KB     | ##################################1   |  92%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    |                                       |   0%
#
#
#
# libtiff-4.5.1        | 508 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 371 KB    | #5                                    |   4%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 517 KB    | #1                                    |   3%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #7                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ##5                                   |   7%
# freetype-2.12.1      | 592 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 371 KB    | ###############################9      |  86%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 517 KB    | ######################8               |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 253 KB    | ##3                                   |   6%
#
#
#
#
#
# libbrotlienc-1.0.9   | 300 KB    | ##################################### | 100%
#
#
#
#
#
# libbrotlienc-1.0.9   | 300 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ####9                                 |  13%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ###7                                  |  10%
#
#
#
#
# zstd-1.5.5           | 599 KB    | ##################################### | 100%
#
#
#
#
# zstd-1.5.5           | 599 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##                                    |   6%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #####3                                |  14%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ##########                            |  27%
#
#
#
#
#
#
#
# brotli-bin-1.0.9     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ######6                               |  18%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.8.4     | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 241 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ###############7                      |  43%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #######7                              |  21%
#
#
#
#
#
#
#
#
#
#
# libwebp-base-1.3.2   | 371 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 351 KB    | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 517 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# unicodedata2-15.1.0  | 517 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 61 KB     | #########6                            |  26%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 253 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 253 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | #####################8                |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 351 KB    | #################################7    |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libpng-1.6.39        | 290 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #########9                            |  27%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 241 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# contourpy-1.2.0      | 241 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | 7                                     |   2%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 61 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# importlib_resources- | 61 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | #############3                        |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.0.9         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ###################                   |  52%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ##########8                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openjpeg-2.5.2       | 351 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | #############################9        |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 31 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ###########6                          |  32%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ################################6     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | #####################2                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | #############################1        |  79%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ############3                         |  33%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ###################################1  |  95%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #############1                        |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ##############                        |  38%
#
#
#
#
#
#
#
#
#
# fonttools-4.51.0     | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ################7                     |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pillow-10.4.0        | 751 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ###################2                  |  52%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ####################8                 |  56%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ######################5               |  61%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ########################6             |  67%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ##########################8           |  73%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | #############################         |  78%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ##############################8       |  83%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ################################6     |  88%
#
#
#
#
#
#
#
#
# matplotlib-base-3.8. | 6.8 MB    | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y seaborn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     seaborn-0.13.2             |   py39hecd8cb5_0         590 KB
#     ------------------------------------------------------------
#                                            Total:         590 KB
#
# The following NEW packages will be INSTALLED:
#
#   seaborn            pkgs/main/osx-64::seaborn-0.13.2-py39hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from sweetviz) (1.26.4)
# Requirement already satisfied: matplotlib>=3.1.3 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from sweetviz) (3.8.4)
# Collecting tqdm>=4.43.0 (from sweetviz)
#   Downloading tqdm-4.66.5-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.4 MB/s eta 0:00:00
# Collecting scipy>=1.3.2 (from sweetviz)
#   Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 787.5 kB/s eta 0:00:00 0:00:01
# Collecting jinja2>=2.11.1 (from sweetviz)
#   Downloading jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: importlib-resources>=1.2.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from sweetviz) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from importlib-resources>=1.2.0->sweetviz) (3.19.2)
# Collecting MarkupSafe>=2.0 (from jinja2>=2.11.1->sweetviz)
#   Downloading MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 522.6 kB/s eta 0:00:0000:0100:01
# Downloading jinja2-3.1.4-py3-none-any.whl (133 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.3/133.3 kB 479.0 kB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.13.1-cp39-cp39-macosx_10_9_x86_64.whl (39.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 519.2 kB/s eta 0:00:0000:0100:03
# Downloading tqdm-4.66.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.4/78.4 kB 393.3 kB/s eta 0:00:00a 0:00:01
# Downloading MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_x86_64.whl (14 kB)
# Installing collected packages: tqdm, scipy, MarkupSafe, jinja2, sweetviz
# Successfully installed MarkupSafe-2.1.5 jinja2-3.1.4 scipy-1.13.1 sweetviz-2.3.1 tqdm-4.66.5

# %%
# !conda install -y unidecode
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - unidecode
#
#
# The following NEW packages will be INSTALLED:
#
#   unidecode          pkgs/main/noarch::unidecode-1.2.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y pyyaml
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - pyyaml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pyyaml-6.0.1               |   py39h6c40b1e_0         172 KB
#     ------------------------------------------------------------
#                                            Total:         172 KB
#
# The following NEW packages will be INSTALLED:
#
#   pyyaml             pkgs/main/osx-64::pyyaml-6.0.1-py39h6c40b1e_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !conda install -y shap
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - shap
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cloudpickle-3.0.0          |   py39hecd8cb5_0          35 KB
#     joblib-1.4.2               |   py39hecd8cb5_0         399 KB
#     libgfortran-5.0.0          |11_3_0_hecd8cb5_28         142 KB
#     libgfortran5-11.3.0        |      h9dfd629_28         1.4 MB
#     libllvm14-14.0.6           |       h91fad77_3        24.1 MB
#     llvmlite-0.43.0            |   py39h6d0c2b6_0         319 KB
#     numba-0.60.0               |   py39h6d0c2b6_0         4.4 MB
#     scikit-learn-1.1.3         |   py39he9d5cce_0         6.5 MB
#     scipy-1.12.0               |   py39hdb2ea58_0        21.9 MB
#     shap-0.42.1                |   py39h3ea8b11_0         585 KB
#     tqdm-4.66.4                |   py39h20db666_0         133 KB
#     ------------------------------------------------------------
#                                            Total:        60.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   cloudpickle        pkgs/main/osx-64::cloudpickle-3.0.0-py39hecd8cb5_0
#   joblib             pkgs/main/osx-64::joblib-1.4.2-py39hecd8cb5_0
#   libgfortran        pkgs/main/osx-64::libgfortran-5.0.0-11_3_0_hecd8cb5_28
#   libgfortran5       pkgs/main/osx-64::libgfortran5-11.3.0-h9dfd629_28
#   libllvm14          pkgs/main/osx-64::libllvm14-14.0.6-h91fad77_3
#   llvm-openmp        pkgs/main/osx-64::llvm-openmp-14.0.6-h0dcd299_0
#   llvmlite           pkgs/main/osx-64::llvmlite-0.43.0-py39h6d0c2b6_0
#   numba              pkgs/main/osx-64::numba-0.60.0-py39h6d0c2b6_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-1.1.3-py39he9d5cce_0
#   scipy              pkgs/main/osx-64::scipy-1.12.0-py39hdb2ea58_0
#   shap               pkgs/main/osx-64::shap-0.42.1-py39h3ea8b11_0
#   slicer             pkgs/main/noarch::slicer-0.0.7-pyhd3eb1b0_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#   tqdm               pkgs/main/osx-64::tqdm-4.66.4-py39h20db666_0
#
#
#
# Downloading and Extracting Packages
# libllvm14-14.0.6     | 24.1 MB   |                                       |   0%
# joblib-1.4.2         | 399 KB    |                                       |   0%
#
# cloudpickle-3.0.0    | 35 KB     |                                       |   0%
#
#
# tqdm-4.66.4          | 133 KB    |                                       |   0%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    |                                       |   0%
#
#
#
#
# llvmlite-0.43.0      | 319 KB    |                                       |   0%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    |                                       |   0%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    |                                       |   0%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   |                                       |   0%
#
#
# tqdm-4.66.4          | 133 KB    | ####4                                 |  12%
#
# libllvm14-14.0.6     | 24.1 MB   |                                       |   0%
# libllvm14-14.0.6     | 24.1 MB   | 1                                     |   0%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | 4                                     |   1%
#
# cloudpickle-3.0.0    | 35 KB     | ##################################### | 100%
#
# cloudpickle-3.0.0    | 35 KB     | ##################################### | 100%
#
#
# tqdm-4.66.4          | 133 KB    | ###################################6  |  96%
#
#
# libllvm14-14.0.6     | 24.1 MB   | 1                                     |   1%
# joblib-1.4.2         | 399 KB    | ###########8                          |  32%
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 2                                     |   1%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ####                                  |  11%
# joblib-1.4.2         | 399 KB    | #################7                    |  48%
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 3                                     |   1%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | 1                                     |   0%
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 4                                     |   1%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | 6                                     |   2%
#
#
#
#
# llvmlite-0.43.0      | 319 KB    | #######4                              |  20%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 5                                     |   2%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #5                                    |   4%
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 6                                     |   2%
# joblib-1.4.2         | 399 KB    | ######################2               |  60%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | #######3                              |  20%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ########1                             |  22%
# joblib-1.4.2         | 399 KB    | ##################################### | 100%
# libllvm14-14.0.6     | 24.1 MB   | 7                                     |   2%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ############6                         |  34%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | 8                                     |   2%
#
#
#
#
# llvmlite-0.43.0      | 319 KB    | ################7                     |  45%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #                                     |   3%
#
#
#
#
# llvmlite-0.43.0      | 319 KB    | ########################1             |  65%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #2                                    |   3%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##############7                       |  40%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    |                                       |   0%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #2                                    |   3%
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #2                                    |   3%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #####1                                |  14%
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #4                                    |   4%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ######3                               |  17%
#
#
#
#
# llvmlite-0.43.0      | 319 KB    | ##################################### | 100%
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #5                                    |   4%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ######################9               |  62%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ######9                               |  19%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #6                                    |   4%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##3                                   |   6%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ########################5             |  66%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | #                                     |   3%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ##                                    |   5%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ####                                  |  11%
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #7                                    |   5%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ######                                |  16%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #######6                              |  21%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | #######                               |  19%
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #8                                    |   5%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ########1                             |  22%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##9                                   |   8%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###2                                  |   9%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | #############################4        |  80%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##############################2       |  82%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ########5                             |  23%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ###############################       |  84%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ########8                             |  24%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##########2                           |  28%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ###################################1  |  95%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##################################### | 100%
#
#
#
# libgfortran5-11.3.0  | 1.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | #########1                            |  25%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #8                                    |   5%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ##########1                           |  27%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #####3                                |  15%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #9                                    |   5%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | ############4                         |  34%
#
#
#
#
#
#
#
#
# libgfortran-5.0.0    | 142 KB    | #############################1        |  79%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##########6                           |  29%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##3                                   |   6%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ######################2               |  60%
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##3                                   |   6%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##########9                           |  29%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ######1                               |  17%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | #########################2            |  68%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###########2                          |  31%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##5                                   |   7%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ###############################3      |  85%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##6                                   |   7%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ############3                         |  33%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   |                                       |   0%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | 3                                     |   1%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #######9                              |  22%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | 5                                     |   1%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | 7                                     |   2%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ########4                             |  23%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
# shap-0.42.1          | 585 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #                                     |   3%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #3                                    |   4%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #############7                        |  37%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #########                             |  24%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #6                                    |   4%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #########3                            |  25%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##############3                       |  39%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###                                   |   8%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #########6                            |  26%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##############5                       |  39%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###1                                  |   8%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##########                            |  27%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##6                                   |   7%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###1                                  |   9%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##8                                   |   8%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###2                                  |   9%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###############2                      |  41%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###2                                  |   9%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##########7                           |  29%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###############6                      |  42%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###########                           |  30%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###2                                  |   9%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###############8                      |  43%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###8                                  |  10%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###3                                  |   9%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ################2                     |  44%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####                                  |  11%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ################5                     |  45%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###4                                  |   9%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####3                                 |  12%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ############1                         |  33%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ################9                     |  46%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###5                                  |  10%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ############5                         |  34%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####9                                 |  13%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###5                                  |  10%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ############9                         |  35%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###6                                  |  10%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #################8                    |  48%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #############2                        |  36%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####5                                |  15%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###7                                  |  10%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####8                                |  16%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #############6                        |  37%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######                                |  16%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##################6                   |  50%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######3                               |  17%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##############2                       |  39%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###8                                  |  10%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###9                                  |  11%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##############6                       |  39%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###################3                  |  52%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######9                               |  19%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######1                              |  19%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ###9                                  |  11%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######3                              |  20%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####                                  |  11%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######6                              |  21%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####                                  |  11%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ####################1                 |  54%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###############5                      |  42%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######7                              |  21%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######9                              |  22%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###############8                      |  43%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ####################6                 |  56%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####1                                 |  11%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ################1                     |  44%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########4                             |  23%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ####################8                 |  56%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####2                                 |  11%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########6                             |  23%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ################7                     |  45%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #####################2                |  58%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####2                                 |  12%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ################9                     |  46%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########2                            |  25%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####3                                 |  12%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #################4                    |  47%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########4                            |  26%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########7                            |  26%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ######################2               |  60%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####5                                 |  12%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ######################5               |  61%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####5                                 |  12%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ######################8               |  62%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################4                   |  50%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #######################1              |  62%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####5                                 |  12%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################6                   |  50%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########9                           |  30%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###################                   |  51%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####6                                 |  13%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########2                          |  30%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###################3                  |  52%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########6                          |  31%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###################8                  |  54%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ########################5             |  66%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####8                                 |  13%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ####################1                 |  55%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############2                         |  33%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####9                                 |  13%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ####################5                 |  55%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############5                         |  34%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ####9                                 |  13%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ####################8                 |  56%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####                                 |  14%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #########################7            |  70%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #####################2                |  57%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####1                                |  14%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##########################1           |  71%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #####################6                |  59%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #############3                        |  36%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####1                                |  14%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #############6                        |  37%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####2                                |  14%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###########################           |  73%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #############9                        |  38%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ######################4               |  61%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####3                                |  14%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ######################7               |  61%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####3                                |  15%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #######################               |  62%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####4                                |  15%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ############################1         |  76%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #######################2              |  63%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############6                       |  40%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####4                                |  15%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ############################3         |  77%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####5                                |  15%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ############################6         |  77%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #######################8              |  64%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############8                       |  40%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ############################9         |  78%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####5                                |  15%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############                       |  41%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #############################2        |  79%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############3                      |  41%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #############################6        |  80%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####7                                |  15%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##############################2       |  82%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #########################1            |  68%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############7                      |  43%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##############################4       |  82%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####7                                |  16%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################                      |  43%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####8                                |  16%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###############################1      |  84%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #########################9            |  70%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################6                     |  45%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##########################1           |  71%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #####9                                |  16%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######                                |  16%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##########################7           |  72%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ################################1     |  87%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################3                    |  47%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######1                               |  17%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ################################7     |  88%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################7                    |  48%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###########################5          |  74%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######1                               |  17%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################9                    |  49%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #################################5    |  91%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######2                               |  17%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################2                   |  49%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | #################################8    |  92%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######3                               |  17%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################6                   |  51%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##################################6   |  94%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ############################8         |  78%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######4                               |  17%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###################################2  |  95%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #############################2        |  79%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###################3                  |  52%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ###################################8  |  97%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #############################8        |  81%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###################6                  |  53%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################                  |  54%
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######5                               |  18%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##############################7       |  83%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######6                               |  18%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###############################2      |  84%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################7                 |  56%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
# numba-0.60.0         | 4.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################                 |  57%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######7                               |  18%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################2                |  58%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######7                               |  18%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################6                |  59%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######8                               |  19%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################9                |  59%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ######9                               |  19%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######################2               |  60%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #################################4    |  90%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######                               |  19%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | #################################8    |  91%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######1                              |  19%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################################1   |  92%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######1                              |  19%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################################5   |  94%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######2                              |  20%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###################################   |  95%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######3                              |  20%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########################1             |  65%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########################3             |  66%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######4                              |  20%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########################8             |  67%
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######5                              |  20%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######6                              |  21%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########################5            |  69%
#
#
#
#
#
#
# scikit-learn-1.1.3   | 6.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######8                              |  21%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #######9                              |  22%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########                              |  22%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########1                             |  22%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########3                             |  23%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########4                             |  23%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########5                             |  23%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########6                             |  23%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########7                             |  24%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########8                             |  24%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########9                             |  24%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ########9                             |  24%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########1                            |  25%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########2                            |  25%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########3                            |  25%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########4                            |  26%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################################5   |  93%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########6                            |  26%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########8                            |  27%
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | #########9                            |  27%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##########                            |  27%
#
#
#
#
#
#
#
#
#
# libllvm14-14.0.6     | 24.1 MB   | ##########1                           |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: /
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done

# %%
# !conda install -y lightgbm
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          45 KB
#     libopenblas-0.3.21         |       h54e7dc3_0         4.9 MB
#     lightgbm-4.5.0             |   py39h6d0c2b6_0         5.4 MB
#     numexpr-2.8.7              |   py39hf6dca73_0         135 KB
#     numpy-1.26.4               |   py39hf6dca73_0          12 KB
#     numpy-base-1.26.4          |   py39hd8f4981_0         6.7 MB
#     scipy-1.12.0               |   py39ha516a68_0        21.9 MB
#     ------------------------------------------------------------
#                                            Total:        39.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   libopenblas        pkgs/main/osx-64::libopenblas-0.3.21-h54e7dc3_0
#   lightgbm           pkgs/main/osx-64::lightgbm-4.5.0-py39h6d0c2b6_0
#
# The following packages will be REMOVED:
#
#   mkl_fft-1.3.8-py39h6c40b1e_0
#   mkl_random-1.2.4-py39ha357a0b_0
#
# The following packages will be UPDATED:
#
#   blas                                              1.0-mkl --> 1.0-openblas
#
# The following packages will be DOWNGRADED:
#
#   numexpr                              2.8.7-py39h827a554_0 --> 2.8.7-py39hf6dca73_0
#   numpy                               1.26.4-py39h827a554_0 --> 1.26.4-py39hf6dca73_0
#   numpy-base                          1.26.4-py39ha186be2_0 --> 1.26.4-py39hd8f4981_0
#   scipy                               1.12.0-py39hdb2ea58_0 --> 1.12.0-py39ha516a68_0
#
#
#
# Downloading and Extracting Packages
# libopenblas-0.3.21   | 4.9 MB    |                                       |   0%
# blas-1.0             | 45 KB     |                                       |   0%
#
# numpy-base-1.26.4    | 6.7 MB    |                                       |   0%
#
#
# lightgbm-4.5.0       | 5.4 MB    |                                       |   0%
#
#
#
# scipy-1.12.0         | 21.9 MB   |                                       |   0%
#
#
#
#
# numpy-1.26.4         | 12 KB     |                                       |   0%
#
#
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | 1                                     |   0%
#
#
# lightgbm-4.5.0       | 5.4 MB    | 1                                     |   0%
#
#
#
# scipy-1.12.0         | 21.9 MB   |                                       |   0%
# blas-1.0             | 45 KB     | #############1                        |  36%
#
# libopenblas-0.3.21   | 4.9 MB    | 9                                     |   3%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #                                     |   3%
#
#
#
# scipy-1.12.0         | 21.9 MB   | 2                                     |   1%
# blas-1.0             | 45 KB     | ##################################### | 100%
# blas-1.0             | 45 KB     | ##################################### | 100%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #7                                    |   5%
#
# libopenblas-0.3.21   | 4.9 MB    | ##4                                   |   7%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ##2                                   |   6%
#
# numpy-base-1.26.4    | 6.7 MB    | 5                                     |   1%
#
#
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ###2                                  |   9%
#
#
#
# scipy-1.12.0         | 21.9 MB   | 3                                     |   1%
#
#
#
#
# numpy-1.26.4         | 12 KB     | ##################################### | 100%
#
#
#
# scipy-1.12.0         | 21.9 MB   | 6                                     |   2%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ####2                                 |  11%
#
# numpy-base-1.26.4    | 6.7 MB    | 6                                     |   2%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #####2                                |  14%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | ######4                               |  17%
#
#
#
#
#
# numexpr-2.8.7        | 135 KB    | ####3                                 |  12%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #1                                    |   3%
#
# numpy-base-1.26.4    | 6.7 MB    | #                                     |   3%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #####6                                |  15%
#
#
#
#
#
# numexpr-2.8.7        | 135 KB    | ###################################1  |  95%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #2                                    |   3%
#
# numpy-base-1.26.4    | 6.7 MB    | #2                                    |   3%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #######2                              |  20%
#
#
#
#
#
# numexpr-2.8.7        | 135 KB    | ##################################### | 100%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ######9                               |  19%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | #######9                              |  22%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #######7                              |  21%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #5                                    |   4%
#
# libopenblas-0.3.21   | 4.9 MB    | #########                             |  24%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ########3                             |  23%
#
# numpy-base-1.26.4    | 6.7 MB    | #7                                    |   5%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #########8                            |  27%
#
# numpy-base-1.26.4    | 6.7 MB    | #8                                    |   5%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #7                                    |   5%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###########6                          |  31%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##1                                   |   6%
#
# numpy-base-1.26.4    | 6.7 MB    | ##2                                   |   6%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #############1                        |  36%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ###########5                          |  31%
#
# numpy-base-1.26.4    | 6.7 MB    | ##4                                   |   7%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | #############9                        |  38%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ############3                         |  33%
#
# numpy-base-1.26.4    | 6.7 MB    | ##5                                   |   7%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###############1                      |  41%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##6                                   |   7%
#
# libopenblas-0.3.21   | 4.9 MB    | ###############8                      |  43%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##7                                   |   7%
#
# libopenblas-0.3.21   | 4.9 MB    | ################5                     |  45%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ############9                         |  35%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | #################6                    |  48%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ##############7                       |  40%
#
# numpy-base-1.26.4    | 6.7 MB    | ###                                   |   8%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###                                   |   8%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###################1                  |  52%
#
# numpy-base-1.26.4    | 6.7 MB    | ###3                                  |   9%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | ####################1                 |  54%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ################6                     |  45%
#
# numpy-base-1.26.4    | 6.7 MB    | ###5                                  |  10%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###3                                  |   9%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #####################6                |  58%
#
# numpy-base-1.26.4    | 6.7 MB    | ###6                                  |  10%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###4                                  |   9%
#
# numpy-base-1.26.4    | 6.7 MB    | ###8                                  |  10%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ######################5               |  61%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###6                                  |  10%
#
# libopenblas-0.3.21   | 4.9 MB    | ########################1             |  65%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ####################                  |  54%
#
# numpy-base-1.26.4    | 6.7 MB    | ####2                                 |  11%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###8                                  |  10%
#
# numpy-base-1.26.4    | 6.7 MB    | ####3                                 |  12%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #########################1            |  68%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | #########################9            |  70%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #####################6                |  58%
#
# numpy-base-1.26.4    | 6.7 MB    | ####5                                 |  12%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####                                  |  11%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ##########################9           |  73%
#
# numpy-base-1.26.4    | 6.7 MB    | ####7                                 |  13%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###########################9          |  76%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #######################5              |  64%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####3                                 |  12%
#
# libopenblas-0.3.21   | 4.9 MB    | ############################9         |  78%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ########################3             |  66%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####5                                 |  12%
#
# libopenblas-0.3.21   | 4.9 MB    | #############################8        |  81%
#
#
# lightgbm-4.5.0       | 5.4 MB    | #########################2            |  68%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####6                                 |  13%
#
# numpy-base-1.26.4    | 6.7 MB    | #####3                                |  14%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ##############################8       |  83%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####8                                 |  13%
#
# numpy-base-1.26.4    | 6.7 MB    | #####5                                |  15%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###############################9      |  86%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####9                                 |  13%
#
# numpy-base-1.26.4    | 6.7 MB    | #####6                                |  15%
#
#
# libopenblas-0.3.21   | 4.9 MB    | #################################     |  89%
#
# numpy-base-1.26.4    | 6.7 MB    | #####8                                |  16%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####1                                |  14%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ##################################2   |  92%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####3                                |  14%
#
# numpy-base-1.26.4    | 6.7 MB    | ######1                               |  17%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ###################################2  |  95%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####4                                |  15%
#
# numpy-base-1.26.4    | 6.7 MB    | ######3                               |  17%
#
#
# libopenblas-0.3.21   | 4.9 MB    | ####################################5 |  99%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####6                                |  15%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ################################1     |  87%
#
# numpy-base-1.26.4    | 6.7 MB    | ######6                               |  18%
#
#
#
# libopenblas-0.3.21   | 4.9 MB    | ##################################### | 100%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ###################################   |  95%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######2                               |  17%
#
# numpy-base-1.26.4    | 6.7 MB    | #######2                              |  20%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ####################################4 |  99%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######4                               |  18%
#
# numpy-base-1.26.4    | 6.7 MB    | #######4                              |  20%
#
# numpy-base-1.26.4    | 6.7 MB    | #######7                              |  21%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######7                               |  18%
#
#
# lightgbm-4.5.0       | 5.4 MB    | ##################################### | 100%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######                               |  19%
#
# numpy-base-1.26.4    | 6.7 MB    | ########1                             |  22%
#
# numpy-base-1.26.4    | 6.7 MB    | ########5                             |  23%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######2                              |  20%
#
# numpy-base-1.26.4    | 6.7 MB    | ########7                             |  24%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######5                              |  20%
#
# numpy-base-1.26.4    | 6.7 MB    | #########                             |  24%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######7                              |  21%
#
# numpy-base-1.26.4    | 6.7 MB    | #########3                            |  25%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########                              |  22%
#
# numpy-base-1.26.4    | 6.7 MB    | #########6                            |  26%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########2                             |  22%
#
# numpy-base-1.26.4    | 6.7 MB    | #########9                            |  27%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########4                             |  23%
#
# numpy-base-1.26.4    | 6.7 MB    | ##########3                           |  28%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########6                             |  23%
#
# numpy-base-1.26.4    | 6.7 MB    | ##########6                           |  29%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########8                             |  24%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########1                            |  25%
#
# numpy-base-1.26.4    | 6.7 MB    | ###########                           |  30%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########3                            |  25%
#
# numpy-base-1.26.4    | 6.7 MB    | ###########3                          |  31%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########5                            |  26%
#
# numpy-base-1.26.4    | 6.7 MB    | ###########7                          |  32%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########7                            |  26%
#
# numpy-base-1.26.4    | 6.7 MB    | ############1                         |  33%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########                            |  27%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########3                           |  28%
#
# numpy-base-1.26.4    | 6.7 MB    | ############5                         |  34%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########6                           |  29%
#
# numpy-base-1.26.4    | 6.7 MB    | ############8                         |  35%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########9                           |  29%
#
# numpy-base-1.26.4    | 6.7 MB    | #############2                        |  36%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########1                          |  30%
#
# numpy-base-1.26.4    | 6.7 MB    | #############5                        |  37%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########4                          |  31%
#
# numpy-base-1.26.4    | 6.7 MB    | #############9                        |  38%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########6                          |  32%
#
# numpy-base-1.26.4    | 6.7 MB    | ##############2                       |  39%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############1                         |  33%
#
# numpy-base-1.26.4    | 6.7 MB    | ##############7                       |  40%
#
# numpy-base-1.26.4    | 6.7 MB    | ###############1                      |  41%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############4                         |  34%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############9                         |  35%
#
# numpy-base-1.26.4    | 6.7 MB    | ###############9                      |  43%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #############4                        |  36%
#
# numpy-base-1.26.4    | 6.7 MB    | ################5                     |  45%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #############7                        |  37%
#
# numpy-base-1.26.4    | 6.7 MB    | ################8                     |  46%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############                        |  38%
#
# numpy-base-1.26.4    | 6.7 MB    | #################1                    |  46%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############4                       |  39%
#
# numpy-base-1.26.4    | 6.7 MB    | #################6                    |  48%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############7                       |  40%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################                    |  49%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############1                      |  41%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################4                   |  50%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############5                      |  42%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################9                   |  51%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############8                      |  43%
#
# numpy-base-1.26.4    | 6.7 MB    | ###################3                  |  52%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################2                     |  44%
#
# numpy-base-1.26.4    | 6.7 MB    | ###################8                  |  54%
#
# numpy-base-1.26.4    | 6.7 MB    | ####################2                 |  55%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################7                     |  45%
#
# numpy-base-1.26.4    | 6.7 MB    | ####################8                 |  56%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################5                    |  47%
#
# numpy-base-1.26.4    | 6.7 MB    | #####################2                |  57%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################                    |  49%
#
# numpy-base-1.26.4    | 6.7 MB    | #####################7                |  59%
#
# numpy-base-1.26.4    | 6.7 MB    | ######################1               |  60%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################4                   |  50%
#
# numpy-base-1.26.4    | 6.7 MB    | ######################5               |  61%
#
# numpy-base-1.26.4    | 6.7 MB    | #######################9              |  65%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################                  |  54%
#
# numpy-base-1.26.4    | 6.7 MB    | ########################9             |  67%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################2                 |  55%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################6                 |  56%
#
# numpy-base-1.26.4    | 6.7 MB    | ##########################            |  70%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################                 |  57%
#
# numpy-base-1.26.4    | 6.7 MB    | ##########################6           |  72%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################4                |  58%
#
# numpy-base-1.26.4    | 6.7 MB    | ###########################1          |  73%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #####################7                |  59%
#
# numpy-base-1.26.4    | 6.7 MB    | ###########################6          |  75%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######################                |  60%
#
# numpy-base-1.26.4    | 6.7 MB    | ############################3         |  77%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######################4               |  61%
#
# numpy-base-1.26.4    | 6.7 MB    | ############################9         |  78%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ######################9               |  62%
#
# numpy-base-1.26.4    | 6.7 MB    | #############################5        |  80%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######################3              |  63%
#
# numpy-base-1.26.4    | 6.7 MB    | ##############################3       |  82%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #######################7              |  64%
#
# numpy-base-1.26.4    | 6.7 MB    | ##############################9       |  84%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########################1             |  65%
#
# numpy-base-1.26.4    | 6.7 MB    | ###############################5      |  85%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ########################5             |  66%
#
# numpy-base-1.26.4    | 6.7 MB    | ################################2     |  87%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########################             |  68%
#
# numpy-base-1.26.4    | 6.7 MB    | ################################8     |  89%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########################4            |  69%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #########################8            |  70%
#
# numpy-base-1.26.4    | 6.7 MB    | #################################7    |  91%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########################2           |  71%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################################3   |  93%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##########################6           |  72%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################################9   |  95%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########################2          |  74%
#
# numpy-base-1.26.4    | 6.7 MB    | ####################################2 |  98%
#
# numpy-base-1.26.4    | 6.7 MB    | ####################################8 |  99%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###########################5          |  75%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ############################          |  76%
#
# numpy-base-1.26.4    | 6.7 MB    | ##################################### | 100%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############################        |  81%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##############################7       |  83%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############################3      |  85%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###############################9      |  86%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################################4     |  88%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ################################9     |  89%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################################4    |  90%
#
#
#
# scipy-1.12.0         | 21.9 MB   | #################################9    |  92%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################################4   |  93%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################################8   |  94%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###################################3  |  95%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ###################################9  |  97%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ####################################4 |  98%
#
#
#
# scipy-1.12.0         | 21.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install japanize_matplotlib
# Out:
# Collecting japanize_matplotlib
#   Using cached japanize_matplotlib-1.1.3-py3-none-any.whl
# Requirement already satisfied: matplotlib in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from japanize_matplotlib) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from matplotlib->japanize_matplotlib) (6.4.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib->japanize_matplotlib) (3.19.2)
# Requirement already satisfied: six>=1.5 in /Users/ishizuka/opt/anaconda3/envs/signate_signatecup2024/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib->japanize_matplotlib) (1.16.0)
# Installing collected packages: japanize_matplotlib
# Successfully installed japanize_matplotlib-1.1.3
